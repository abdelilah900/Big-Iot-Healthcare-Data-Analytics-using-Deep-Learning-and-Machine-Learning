# %% [markdown]
# ## Big Iot Healthcare Data Analytics using Deep Learning and Machine Learning

# %%
# !pip install  neurokit2
# Out:
# Collecting neurokit2
#   Downloading neurokit2-0.2.0-py2.py3-none-any.whl (1.2 MB)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from neurokit2) (1.21.5)
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (from neurokit2) (1.4.2)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\lib\site-packages (from neurokit2) (3.5.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from neurokit2) (1.0.2)
# Requirement already satisfied: scipy in c:\users\hp\anaconda3\lib\site-packages (from neurokit2) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->neurokit2) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->neurokit2) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->neurokit2) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->neurokit2) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->neurokit2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->neurokit2) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->neurokit2) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->neurokit2) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->neurokit2) (1.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->neurokit2) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas->neurokit2) (2021.3)
# Installing collected packages: neurokit2
# Successfully installed neurokit2-0.2.0

# %%
import warnings
warnings.filterwarnings('ignore')
import neurokit2 as nk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Simulated_ECG = nk.ecg_simulate(duration=15, sampling_rate=200,noise=0.01, heart_rate=100)
Simulated_ECG
# Out:
# array([1.1286344 , 1.01761339, 0.74382499, ..., 0.22745569, 0.53706692,
#        0.85568054])

# %%
print(len(Simulated_ECG))
# Out:
# 3000

# %%
nk.signal_plot(Simulated_ECG, sampling_rate=200)

# %%
data_healthcare=pd.DataFrame(Simulated_ECG,columns=["ECG"])

# %%
data_healthcare
# Out:
#            ECG
# 0     1.128634
# 1     1.017613
# 2     0.743825
# 3     0.396882
# 4     0.073943
# ...        ...
# 2995 -0.173889
# 2996 -0.018366
# 2997  0.227456
# 2998  0.537067
# 2999  0.855681
#
# [3000 rows x 1 columns]

# %%
rsp_sim = nk.rsp_simulate(duration=15, sampling_rate=200,noise=0.01,respiratory_rate=100, method="sinusoidal")

# %%
rsp_sim.reshape(3000,1)
# Out:
# array([[ 0.00711017],
#        [ 0.03320715],
#        [ 0.05909851],
#        ...,
#        [-0.10426129],
#        [-0.07865216],
#        [-0.05267467]])

# %%
len(rsp_sim)
# Out:
# 3000

# %%
data_healthcare.insert(1,"RSP",rsp_sim,True)

# %%
data_healthcare
# Out:
#            ECG       RSP
# 0     1.128634  0.007110
# 1     1.017613  0.033207
# 2     0.743825  0.059099
# 3     0.396882  0.084725
# 4     0.073943  0.110027
# ...        ...       ...
# 2995 -0.173889 -0.154165
# 2996 -0.018366 -0.129450
# 2997  0.227456 -0.104261
# 2998  0.537067 -0.078652
# 2999  0.855681 -0.052675
#
# [3000 rows x 2 columns]

# %%
import pandas as pd
import numpy as np
# create a random number generator that will be used to set the randomness
rng = np.random.RandomState(1)
temp_min, temp_max =96,99
body_temp = rng.uniform(temp_min, temp_max, size=3000)
body_temp
# Out:
# array([97.25106601, 98.16097348, 96.00034312, ..., 97.31861731,
#        96.50543091, 97.58726163])

# %%
data_healthcare.insert(1,"body_temp",body_temp,True)

# %%
data_healthcare
# Out:
#            ECG  body_temp       RSP
# 0     1.128634  97.251066  0.007110
# 1     1.017613  98.160973  0.033207
# 2     0.743825  96.000343  0.059099
# 3     0.396882  96.906998  0.084725
# 4     0.073943  96.440268  0.110027
# ...        ...        ...       ...
# 2995 -0.173889  98.508529 -0.154165
# 2996 -0.018366  96.642441 -0.129450
# 2997  0.227456  97.318617 -0.104261
# 2998  0.537067  96.505431 -0.078652
# 2999  0.855681  97.587262 -0.052675
#
# [3000 rows x 3 columns]

# %%
pip install simglucose
# Out:
# Collecting simglucose
#   Downloading simglucose-0.2.3.tar.gz (602 kB)
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (from simglucose) (1.4.2)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from simglucose) (1.21.5)
# Requirement already satisfied: scipy in c:\users\hp\anaconda3\lib\site-packages (from simglucose) (1.7.3)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\lib\site-packages (from simglucose) (3.5.1)
# Collecting pathos
#   Downloading pathos-0.2.9-py3-none-any.whl (76 kB)
# Collecting gym==0.9.4
#   Downloading gym-0.9.4.tar.gz (157 kB)
# Requirement already satisfied: requests>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from gym==0.9.4->simglucose) (2.27.1)
# Requirement already satisfied: six in c:\users\hp\anaconda3\lib\site-packages (from gym==0.9.4->simglucose) (1.16.0)
# Collecting pyglet>=1.2.0
#   Downloading pyglet-1.5.26-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.0->gym==0.9.4->simglucose) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.0->gym==0.9.4->simglucose) (2022.5.18.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.0->gym==0.9.4->simglucose) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.0->gym==0.9.4->simglucose) (1.26.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->simglucose) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->simglucose) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->simglucose) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->simglucose) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->simglucose) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->simglucose) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->simglucose) (1.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas->simglucose) (2021.3)
# Collecting dill>=0.3.5.1
#   Downloading dill-0.3.5.1-py2.py3-none-any.whl (95 kB)
# Collecting multiprocess>=0.70.13
#   Downloading multiprocess-0.70.13-py39-none-any.whl (132 kB)
# Collecting ppft>=1.7.6.5
#   Downloading ppft-1.7.6.5-py2.py3-none-any.whl (52 kB)
# Collecting pox>=0.3.1
#   Downloading pox-0.3.1-py2.py3-none-any.whl (28 kB)
# Building wheels for collected packages: simglucose, gym
#   Building wheel for simglucose (setup.py): started
#   Building wheel for simglucose (setup.py): finished with status 'done'
#   Created wheel for simglucose: filename=simglucose-0.2.3-py3-none-any.whl size=42479 sha256=4ec892a858d9f34ad15b3ca4ac02c0a7812362549ad4ce747e997f4c628fdb8d
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\a4\7d\0a\91a450aa30cf95ddcfff95baf0e1db6e3d278822a3bf071f53
#   Building wheel for gym (setup.py): started
#   Building wheel for gym (setup.py): finished with status 'done'
#   Created wheel for gym: filename=gym-0.9.4-py3-none-any.whl size=215478 sha256=0f9602a8e0a857590c8205d72c7676712534f57772714311281d1c12556a26c3
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\51\ae\71\c6d85ee6f2a71f6b3c6f895fe6498c5bc62b0064991d08a536
# Successfully built simglucose gym
# Installing collected packages: dill, pyglet, ppft, pox, multiprocess, pathos, gym, simglucose
# Successfully installed dill-0.3.5.1 gym-0.9.4 multiprocess-0.70.13 pathos-0.2.9 pox-0.3.1 ppft-1.7.6.5 pyglet-1.5.26 simglucose-0.2.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from simglucose.simulation.env import T1DSimEnv
from simglucose.controller.basal_bolus_ctrller import BBController
from simglucose.sensor.cgm import CGMSensor
from simglucose.actuator.pump import InsulinPump
from simglucose.patient.t1dpatient import T1DPatient
from simglucose.simulation.scenario_gen import RandomScenario
from simglucose.simulation.scenario import CustomScenario
from simglucose.simulation.sim_engine import SimObj, sim, batch_sim
from datetime import timedelta
from datetime import datetime

# specify start_time as the beginning of today
dt = datetime(2022,5,20,22,16,0)
now = datetime.now()
print(now)
start_time = datetime.combine(dt.date(), datetime.min.time())

# --------- Create Random Scenario --------------
# Specify results saving path
path = './results'

# Create a simulation environment
patient = T1DPatient.withName('adolescent#001')
sensor = CGMSensor.withName('Dexcom', seed=1)
pump = InsulinPump.withName('Insulet')
scenario = RandomScenario(start_time=start_time, seed=1)
env = T1DSimEnv(patient, sensor, pump, scenario)

# Create a controller
controller = BBController()

# Put them together to create a simulation object
s1 = SimObj(env, controller, timedelta(days=7), animate=False, path=path)
results1 = sim(s1)
print(results1)
data2=pd.DataFrame(results1)
# Out:
# 2022-08-09 15:04:36.647379
# Process ID: 9492
# Simulation starts ...
# Simulation Completed!
#                              BG         CGM  CHO   insulin      LBGI  \
# Time
# 2022-05-20 00:00:00  149.020000  165.793949  0.0  0.013933  0.000000
# 2022-05-20 00:03:00  149.020000  161.582022  0.0  0.013933  0.000000
# 2022-05-20 00:06:00  159.239373  0.013933
# 2022-05-20 00:09:00  157.472710  0.013933
# 2022-05-20 00:12:00  156.108950  0.013933
# ...                         ...       ...
# 2022-05-26 23:48:00   82.020860  0.013933
# 2022-05-26 23:51:00   83.620499  0.013933
# 2022-05-26 23:54:00   85.494805  0.013933
# 2022-05-26 23:57:00   87.698967  0.013933
# 2022-05-27 00:00:00   90.154322       NaN
#
# [3361 rows x 2 columns]

# %%
data_glucose_insulin_V2=data_glucose_insulin.reset_index()

# %%
data_glucose_insulin_V2
# Out:
#                     Time         CGM   insulin
# 0    2022-05-20 00:00:00  165.793949  0.013933
# 1    2022-05-20 00:03:00  161.582022  0.013933
# 2    2022-05-20 00:06:00  159.239373  0.013933
# 3    2022-05-20 00:09:00  157.472710  0.013933
# 4    2022-05-20 00:12:00  156.108950  0.013933
# ...                  ...         ...       ...
# 3356 2022-05-26 23:48:00   82.020860  0.013933
# 3357 2022-05-26 23:51:00   83.620499  0.013933
# 3358 2022-05-26 23:54:00   85.494805  0.013933
# 3359 2022-05-26 23:57:00   87.698967  0.013933
# 3360 2022-05-27 00:00:00   90.154322       NaN
#
# [3361 rows x 3 columns]

# %%
data_glucose_insulin_V2=data_glucose_insulin_V2[:3000]

# %%
data_glucose_insulin_V3=data_glucose_insulin_V2[["CGM","insulin"]]

# %%
data_glucose_insulin_V3
# Out:
#              CGM   insulin
# 0     165.793949  0.013933
# 1     161.582022  0.013933
# 2     159.239373  0.013933
# 3     157.472710  0.013933
# 4     156.108950  0.013933
# ...          ...       ...
# 2995  158.557501  0.013933
# 2996  158.349722  0.013933
# 2997  155.566524  0.013933
# 2998  149.531043  0.013933
# 2999  145.156558  0.013933
#
# [3000 rows x 2 columns]

# %%
data_healthcare.insert(1,"CGM",data_glucose_insulin_V3["CGM"],True)

# %%
data_healthcare.insert(1,"insulin",data_glucose_insulin_V3["insulin"],True)

# %%
data_healthcare
# Out:
#            ECG   insulin         CGM  body_temp       RSP
# 0     1.128634  0.013933  165.793949  97.251066  0.007110
# 1     1.017613  0.013933  161.582022  98.160973  0.033207
# 2     0.743825  0.013933  159.239373  96.000343  0.059099
# 3     0.396882  0.013933  157.472710  96.906998  0.084725
# 4     0.073943  0.013933  156.108950  96.440268  0.110027
# ...        ...       ...         ...        ...       ...
# 2995 -0.173889  0.013933  158.557501  98.508529 -0.154165
# 2996 -0.018366  0.013933  158.349722  96.642441 -0.129450
# 2997  0.227456  0.013933  155.566524  97.318617 -0.104261
# 2998  0.537067  0.013933  149.531043  96.505431 -0.078652
# 2999  0.855681  0.013933  145.156558  97.587262 -0.052675
#
# [3000 rows x 5 columns]

# %%
data_healthcare['date'] = pd.date_range(start='23/5/2022', periods=len(data_healthcare), freq='S')

# %%
data_healthcare
# Out:
#            ECG   insulin         CGM  body_temp       RSP                date
# 0     1.128634  0.013933  165.793949  97.251066  0.007110 2022-05-23 00:00:00
# 1     1.017613  0.013933  161.582022  98.160973  0.033207 2022-05-23 00:00:01
# 2     0.743825  0.013933  159.239373  96.000343  0.059099 2022-05-23 00:00:02
# 3     0.396882  0.013933  157.472710  96.906998  0.084725 2022-05-23 00:00:03
# 4     0.073943  0.013933  156.108950  96.440268  0.110027 2022-05-23 00:00:04
# ...        ...       ...         ...        ...       ...                 ...
# 2995 -0.173889  0.013933  158.557501  98.508529 -0.154165 2022-05-23 00:49:55
# 2996 -0.018366  0.013933  158.349722  96.642441 -0.129450 2022-05-23 00:49:56
# 2997  0.227456  0.013933  155.566524  97.318617 -0.104261 2022-05-23 00:49:57
# 2998  0.537067  0.013933  149.531043  96.505431 -0.078652 2022-05-23 00:49:58
# 2999  0.855681  0.013933  145.156558  97.587262 -0.052675 2022-05-23 00:49:59
#
# [3000 rows x 6 columns]

# %%
data_healthcare.to_csv("data_healthcare.csv",index=False)

# %%
data_healthcare['date'] = pd.to_datetime(data_healthcare['date'])

# %%
data_healthcare
# Out:
#            ECG   insulin         CGM  body_temp       RSP                date
# 0     1.128634  0.013933  165.793949  97.251066  0.007110 2022-05-23 00:00:00
# 1     1.017613  0.013933  161.582022  98.160973  0.033207 2022-05-23 00:00:01
# 2     0.743825  0.013933  159.239373  96.000343  0.059099 2022-05-23 00:00:02
# 3     0.396882  0.013933  157.472710  96.906998  0.084725 2022-05-23 00:00:03
# 4     0.073943  0.013933  156.108950  96.440268  0.110027 2022-05-23 00:00:04
# ...        ...       ...         ...        ...       ...                 ...
# 2995 -0.173889  0.013933  158.557501  98.508529 -0.154165 2022-05-23 00:49:55
# 2996 -0.018366  0.013933  158.349722  96.642441 -0.129450 2022-05-23 00:49:56
# 2997  0.227456  0.013933  155.566524  97.318617 -0.104261 2022-05-23 00:49:57
# 2998  0.537067  0.013933  149.531043  96.505431 -0.078652 2022-05-23 00:49:58
# 2999  0.855681  0.013933  145.156558  97.587262 -0.052675 2022-05-23 00:49:59
#
# [3000 rows x 6 columns]

# %%
data_healthcare['date']
# Out:
# 0      2022-05-23 00:00:00
# 1      2022-05-23 00:00:01
# 2      2022-05-23 00:00:02
# 3      2022-05-23 00:00:03
# 4      2022-05-23 00:00:04
#                ...
# 2995   2022-05-23 00:49:55
# 2996   2022-05-23 00:49:56
# 2997   2022-05-23 00:49:57
# 2998   2022-05-23 00:49:58
# 2999   2022-05-23 00:49:59
# Name: date, Length: 3000, dtype: datetime64[ns]

# %%
data_healthcare = data_healthcare.set_index('date')

# %%
data_healthcare
# Out:
#                           ECG   insulin         CGM  body_temp       RSP
# date
# 2022-05-23 00:00:00  1.128634  0.013933  165.793949  97.251066  0.007110
# 2022-05-23 00:00:01  1.017613  0.013933  161.582022  98.160973  0.033207
# 2022-05-23 00:00:02  0.743825  0.013933  159.239373  96.000343  0.059099
# 2022-05-23 00:00:03  0.396882  0.013933  157.472710  96.906998  0.084725
# 2022-05-23 00:00:04  0.073943  0.013933  156.108950  96.440268  0.110027
# ...                       ...       ...         ...        ...       ...
# 2022-05-23 00:49:55 -0.173889  0.013933  158.557501  98.508529 -0.154165
# 2022-05-23 00:49:56 -0.018366  0.013933  158.349722  96.642441 -0.129450
# 2022-05-23 00:49:57  0.227456  0.013933  155.566524  97.318617 -0.104261
# 2022-05-23 00:49:58  0.537067  0.013933  149.531043  96.505431 -0.078652
# 2022-05-23 00:49:59  0.855681  0.013933  145.156558  97.587262 -0.052675
#
# [3000 rows x 5 columns]

# %%
data_healthcare['body_temp'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
data_healthcare['CGM'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
data_healthcare.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=2, ncols=2,dpi=160, figsize=(15,10))
for i, ax in enumerate(axes.flatten()):
    data = data_healthcare[data_healthcare.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    ax.set_title(data_healthcare.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)
plt.tight_layout();

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(data_healthcare)
data_healthcare=scaler.transform(data_healthcare)

# %%
data_healthcare
# Out:
# array([[0.95314819, 0.        , 0.8638245 , 0.41700712, 0.50783499],
#        [0.88424582, 0.        , 0.83044165, 0.72038199, 0.53346389],
#        [0.71432602, 0.        , 0.81187431, 0.        , 0.55889086],
#        ...,
#        [0.39385454, 0.        , 0.78276408, 0.43952959, 0.3984611 ],
#        [0.58600688, 0.        , 0.73492812, 0.16840278, 0.4236109 ],
#        [0.78374632, 0.        , 0.70025687, 0.52909907, 0.44912246]])

# %%
data_healthcare=pd.DataFrame(data_healthcare, columns=["ECG","insulin","CGM","body_temp","RSP"])

# %%
import numpy as np
def data_to_X_y3(data_healthcare, window_size=10):
    data_healthcare_as_np = data_healthcare.to_numpy()
    X = []
    y = []
    for i in range(len(data_healthcare_as_np)-window_size):
        row = [r for r in data_healthcare_as_np[i:i+window_size]]
        X.append(row)
        label = [data_healthcare_as_np[i+window_size][0], data_healthcare_as_np[i+window_size][1],data_healthcare_as_np[i+window_size][2],data_healthcare_as_np[i+window_size][3],data_healthcare_as_np[i+window_size][4]]
        y.append(label)
    return np.array(X), np.array(y)

# %%
X3, y3 = data_to_X_y3(data_healthcare,300)
X3.shape, y3.shape
# Out:
# ((2700, 300, 5), (2700, 5))

# %%
X3_train, y3_train = X3[:1900], y3[:1900]
X3_val, y3_val = X3[1900:2300], y3[1900:2300]
X3_test, y3_test = X3[2300:], y3[2300:]
X3_train.shape, y3_train.shape, X3_val.shape, y3_val.shape, X3_test.shape, y3_test.shape
# Out:
# ((1900, 300, 5), (1900, 5), (400, 300, 5), (400, 5), (400, 300, 5), (400, 5))

# %%
from keras.models import Sequential
from tensorflow.keras.layers import InputLayer
from keras.layers.core import Dense, Activation, Dropout
from keras.layers import LSTM
from keras.models import Sequential

# %%
model1 = Sequential()
model1.add(InputLayer((300, 5)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(5, 'linear'))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                17920
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 5)                 45
#
# =================================================================
# Total params: 18,485
# Trainable params: 18,485
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError 
from keras.optimizers import Adam

# %%
cp1 = ModelCheckpoint('model1/', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X3_train, y3_train, validation_data=(X3_val, y3_val), epochs=70, callbacks=[cp1])
# Out:
# Epoch 1/70
# 60/60 [==============================] - ETA: 0s - loss: 0.1379 - root_mean_squared_error: 0.3714
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 60/60 [==============================] - 20s 280ms/step - loss: 0.1379 - root_mean_squared_error: 0.3714 - val_loss: 0.0877 - val_root_mean_squared_error: 0.2961
# Epoch 2/70
# 60/60 [==============================] - ETA: 0s - loss: 0.
- val_loss: 0.0265 - val_root_mean_squared_error: 0.1629
# Epoch 24/70
# 60/60 [==============================] - ETA: 0s - loss: 0.0289 - root_mean_squared_error: 0.1700
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 60/60 [==============================] - 25s 414ms/step - loss: 0.0289 - root_mean_squared_error: 0.1700 - val_loss: 0.0259 - val_root_mean_squared_error: 0.1610
# Epoch 25/70
# 60/60 [==============================] - ETA: 0s - loss: 0.0285 - root_mean_squared_error: 0.1688
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 60/60 [==============================] - 19s 316ms/step - loss: 0.0285 - root_mean_squared_error: 0.1688 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1604
# Epoch 26/70
# 60/60 [==============================] - ETA: 0s - loss: 0.0280 - root_mean_squared_error: 0.1674
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 60/60 [==============================] - 20s 334ms/step - loss: 0.0280 - root_mean_squared_error: 0.1674 - val_loss: 0.0253 - val_root_mean_squared_error: 0.1590
# Epoch 27/70
# 60/60 [==============================] - ETA: 0s - loss: 0.0276 - root_mean_squared_error: 0.1662
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 60/60 [==============================] - 15s 253ms/step - loss: 0.0276 - root_mean_squared_error: 0.1662 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1579
# Epoch 28/70
# 60/60 [==============================] - ETA: 0s - loss: 0.0272 - root_mean_squared_error: 0.1648
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 60/60 [==============================] - 15s 256ms/step - loss: 0.0272 - root_mean_squared_error: 0.1648 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1568
# Epoch 29/70
# 60/60 [==============================] - ETA: 0s - loss: 0.0268 - root_mean_squared_error: 0.1637
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 60/60 [==============================] - 18s 302ms/step - loss: 0.0268 - root_mean_squared_error: 0.1637 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1559
# Epoch 30/70
# 60/60 [==============================] - ETA: 0s - loss: 0.0265 - root_mean_squared_error: 0.1627
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 60/60 [==============================] - 18s 305ms/step - loss: 0.0265 - root_mean_squared_error: 0.1627 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1555
# Epoch 31/70
# 60/60 [==============================] - ETA: 0s - loss: 0.0262 - root_mean_squared_error: 0.1618
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 60/60 [==============================] - 25s 430ms/step - loss: 0.0262 - root_mean_squared_error: 0.1618 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1543
# Epoch 32/70
# 60/60 [==============================] - ETA: 0s - loss: 0.0259 - root_mean_squared_error: 0.1608
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 60/60 [==============================] - 25s 421ms/step - loss: 0.0259 - root_mean_squared_error: 0.1608 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1541
# Epoch 33/70
# 60/60 [==============================] - ETA: 0s - loss: 0.0256 - root_mean_squared_error: 0.1599
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 60/60 [==============================] - 20s 337ms/step - loss: 0.0256 - root_mean_squared_error: 0.1599 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1531
# Epoch 34/70
# 60/60 [==============================] - 10s 166ms/step - loss: 0.0254 - root_mean_squared_error: 0.1592 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1541
# Epoch 35/70
# 45/60 [=====================>........] - ETA: 2s - loss: 0.0251 - root_mean_squared_error: 0.1585

# %%
def plot_predictions2(model, X, y, start=0, end=30):
    predictions = model.predict(X)
    ECG_preds, insulin_preds,CGM_preds,body_temp_preds,RSP_preds = predictions[:, 0],       predictions[:,1],predictions[:,2],predictions[:, 3],predictions[:, 4]
    ECG_actuals, insulin_actuals,body_temp_actuals,CGM_actuals,RSP_actuals = y[:, 0], y[:, 1],y[:, 2],y[:, 3],y[:, 4]
    df = pd.DataFrame(data={'ECG Predictions': ECG_preds,
                          'ECG Actuals':ECG_actuals,
                          'insulin Predictions': insulin_preds,
                          'insulin Actuals': insulin_actuals,
                          'body_temp Predictions': body_temp_preds,
                          'body_temp Actuals': body_temp_actuals,
                          'CGM Predictions': CGM_preds,
                          'CGM Actuals': CGM_actuals,
                            'RSP Predictions': RSP_preds,
                          'RSP Actuals': RSP_actuals
                          })
    plt.plot(df['ECG Predictions'][start:end])
    plt.plot(df['ECG Actuals'][start:end])
    plt.plot(df['insulin Predictions'][start:end])
    plt.plot(df['insulin Actuals'][start:end])
    plt.plot(df['body_temp Predictions'][start:end])
    plt.plot(df['body_temp Actuals'][start:end])
    plt.plot(df['CGM Predictions'][start:end])
    plt.plot(df['CGM Actuals'][start:end])
    plt.plot(df['RSP Predictions'][start:end])
    plt.plot(df['RSP Actuals'][start:end])
    return df[start:end]

# %%
plot_predictions2(model1, X3_test, y3_test)
# Out:
# 13/13 [==============================] - 1s 56ms/step
#     ECG Predictions  ECG Actuals  insulin Predictions  insulin Actuals  \
#
#     RSP Predictions  RSP Actuals
# 0          0.055966     0.066322
# 1          0.048977     0.054176
# 2          0.040219     0.043296
# 3          0.004883     0.033710
# 4          0.025979     0.025440
# 5          0.031239     0.018506
# 6          0.034479     0.012925
# 7          0.038163     0.008708
# 8          0.033283     0.005866
# 9          0.036131     0.004403
# 10         0.031080     0.004322
# 11         0.027453     0.005620
# 12         0.024868     0.008292
# 13         0.033199     0.012329
# 14         0.036899     0.017718
# 15         0.034764     0.024442
# 16         0.046263     0.032483
# 17         0.057964     0.041816
# 18         0.060876     0.052413
# 19         0.084130     0.064245
# 20         0.093856     0.077275
# 21         0.108678     0.091467
# 22         0.125017     0.106780
# 23         0.145102     0.123168
# 24         0.151025     0.140587
# 25         0.171757     0.158984
# 26         0.175629     0.178309
# 27         0.195520     0.198505
# 28         0.217056     0.219516
# 29         0.230354     0.241281

# %%
from keras.layers.convolutional import Conv1D
from keras.layers import Flatten
model2= Sequential()
model2.add(InputLayer((300, 5)))
model2.add(Conv1D(64, kernel_size=2, activation='relu'))
model2.add(Flatten())
model2.add(Dense(8, 'relu'))
model2.add(Dense(5, 'linear'))
model2.summary()

cp2 = ModelCheckpoint('model2/', save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (None, 299, 64)           704
#
#  flatten_5 (Flatten)         (None, 19136)             0
#
#  dense_16 (Dense)            (None, 8)                 153096
#
#  dense_17 (Dense)            (None, 5)                 45
#
# =================================================================
# Total params: 153,845
# Trainable params: 153,845
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.fit(X3_train, y3_train, validation_data=(X3_val, y3_val), epochs=80, callbacks=[cp2])
# Out:
# Epoch 1/80
# 58/60 [============================>.] - ETA: 0s - loss: 0.0407 - root_mean_squared_error: 0.2018
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 60/60 [==============================] - 2s 26ms/step - loss: 0.0405 - root_mean_squared_error: 0.2012 - val_loss: 0.0287 - val_root_mean_squared_error: 0.1695
# Epoch 2/80
# 60/60 [==============================] - ETA: 0s - loss: 0.0275 - root_mean_squared_error: 0.1657
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 60/60 [==============================] - 1s 24ms/step - loss: 0.0275 - root_mean_squared_error: 0.1657 - val_loss: 0.0255 - val_root_mean_squared_error: 0.1596
# Epoch 3/80
# 57/60 [===========================>..] - ETA: 0s - loss: 0.0252 - root_mean_squared_error: 0.1587
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 60/60 [==============================] - 2s 38ms/step - loss: 0.0253 - root_mean_squared_error: 0.1590 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1529
# Epoch 4/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0240 - root_mean_squared_error: 0.1550 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1559
# Epoch 5/80
# 55/60 [==========================>...] - ETA: 0s - loss: 0.0226 - root_mean_squared_error: 0.1502
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 60/60 [==============================] - 1s 23ms/step - loss: 0.0228 - root_mean_squared_error: 0.1509 - val_loss: 0.0228 - val_root_mean_squared_error: 0.1511
# Epoch 6/80
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0218 - root_mean_squared_error: 0.1477 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1540
# Epoch 7/80
# 57/60 [===========================>..] - ETA: 0s - loss: 0.0214 - root_mean_squared_error: 0.1462
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 60/60 [==============================] - 2s 28ms/step - loss: 0.0213 - root_mean_squared_error: 0.1460 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1497
# Epoch 8/80
# 55/60 [==========================>...] - ETA: 0s - loss: 0.0208 - root_mean_squared_error: 0.1443
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 60/60 [==============================] - 1s 23ms/step - loss: 0.0207 - root_mean_squared_error: 0.1438 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1466
# Epoch 9/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0198 - root_mean_squared_error: 0.1409 - val_loss: 0.0220 - val_root_mean_squared_error: 0.1483
# Epoch 10/80
# 58/60 [============================>.] - ETA: 0s - loss: 0.0194 - root_mean_squared_error: 0.1393
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 60/60 [==============================] - 1s 24ms/step - loss: 0.0194 - root_mean_squared_error: 0.1392 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1448
# Epoch 11/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0188 - root_mean_squared_error: 0.1370 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1474
# Epoch 12/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0186 - root_mean_squared_error: 0.1364 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1498
# Epoch 13/80
# 59/60 [============================>.] - ETA: 0s - loss: 0.0180 - root_mean_squared_error: 0.1343
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 60/60 [==============================] - 2s 25ms/step - loss: 0.0180 - root_mean_squared_error: 0.1342 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1443
# Epoch 14/80
# 58/60 [============================>.] - ETA: 0s - loss: 0.0178 - root_mean_squared_error: 0.1334
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 60/60 [==============================] - 2s 27ms/step - loss: 0.0178 - root_mean_squared_error: 0.1334 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1435
# Epoch 15/80
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0174 - root_mean_squared_error: 0.1319 - val_loss: 0.0232 - val_root_mean_squared_error: 0.1522
# Epoch 16/80
# 60/60 [==============================] - 1s 11ms/step - loss: 0.0172 - root_mean_squared_error: 0.1312 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1439
# Epoch 17/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0168 - root_mean_squared_error: 0.1296 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1459
# Epoch 18/80
# 56/60 [===========================>..] - ETA: 0s - loss: 0.0166 - root_mean_squared_error: 0.1289
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 60/60 [==============================] - 2s 25ms/step - loss: 0.0165 - root_mean_squared_error: 0.1286 - val_loss: 0.0202 - val_root_mean_squared_error: 0.1420
# Epoch 19/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0160 - root_mean_squared_error: 0.1264 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1454
# Epoch 20/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0156 - root_mean_squared_error: 0.1249 - val_loss: 0.0211 - val_root_mean_squared_error: 0.1451
# Epoch 21/80
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0154 - root_mean_squared_error: 0.1240 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1428
# Epoch 22/80
# 58/60 [============================>.] - ETA: 0s - loss: 0.0151 - root_mean_squared_error: 0.1228
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model2\assets
# INFO:tensorflow:Assets written to: model2\assets
# 60/60 [==============================] - 2s 27ms/step - loss: 0.0151 - root_mean_squared_error: 0.1229 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1415
# Epoch 23/80
# 60/60 [==============================] - 1s 11ms/step - loss: 0.0150 - root_mean_squared_error: 0.1225 - val_loss: 0.0203 - val_root_mean_squared_error: 0.1424
# Epoch 24/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0146 - root_mean_squared_error: 0.1206 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1435
# Epoch 25/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0144 - root_mean_squared_error: 0.1202 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1432
# Epoch 26/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0143 - root_mean_squared_error: 0.1194 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1419
# Epoch 27/80
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0141 - root_mean_squared_error: 0.1187 - val_loss: 0.0202 - val_root_mean_squared_error: 0.1422
# Epoch 28/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0138 - root_mean_squared_error: 0.1176 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1432
# Epoch 29/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0135 - root_mean_squared_error: 0.1163 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1472
# Epoch 30/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1437
# Epoch 31/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0136 - root_mean_squared_error: 0.1167 - val_loss: 0.0202 - val_root_mean_squared_error: 0.1423
# Epoch 32/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0133 - root_mean_squared_error: 0.1152 - val_loss: 0.0209 - val_root_mean_squared_error: 0.1445
# Epoch 33/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0129 - root_mean_squared_error: 0.1138 - val_loss: 0.0207 - val_root_mean_squared_error: 0.1439
# Epoch 34/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0128 - root_mean_squared_error: 0.1130 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1432
# Epoch 35/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0128 - root_mean_squared_error: 0.1133 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1428
# Epoch 36/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0127 - root_mean_squared_error: 0.1125 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1449
# Epoch 37/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0125 - root_mean_squared_error: 0.1118 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1450
# Epoch 38/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0123 - root_mean_squared_error: 0.1109 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1436
# Epoch 39/80
# 60/60 [==============================] - 1s 11ms/step - loss: 0.0121 - root_mean_squared_error: 0.1100 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1463
# Epoch 40/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0117 - root_mean_squared_error: 0.1084 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1442
# Epoch 41/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1457
# Epoch 42/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0118 - root_mean_squared_error: 0.1087 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1449
# Epoch 43/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0116 - root_mean_squared_error: 0.1076 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1498
# Epoch 44/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0114 - root_mean_squared_error: 0.1069 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1473
# Epoch 45/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0111 - root_mean_squared_error: 0.1053 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1457
# Epoch 46/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0110 - root_mean_squared_error: 0.1048 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1457
# Epoch 47/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0108 - root_mean_squared_error: 0.1037 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1473
# Epoch 48/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0107 - root_mean_squared_error: 0.1034 - val_loss: 0.0220 - val_root_mean_squared_error: 0.1483
# Epoch 49/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0108 - root_mean_squared_error: 0.1037 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1464
# Epoch 50/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0104 - root_mean_squared_error: 0.1020 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1461
# Epoch 51/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0104 - root_mean_squared_error: 0.1022 - val_loss: 0.0223 - val_root_mean_squared_error: 0.1493
# Epoch 52/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0102 - root_mean_squared_error: 0.1010 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1496
# Epoch 53/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0099 - root_mean_squared_error: 0.0996 - val_loss: 0.0225 - val_root_mean_squared_error: 0.1501
# Epoch 54/80
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0100 - root_mean_squared_error: 0.1000 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1478
# Epoch 55/80
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0098 - root_mean_squared_error: 0.0989 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1491
# Epoch 56/80
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0096 - root_mean_squared_error: 0.0980 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1476
# Epoch 57/80
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0096 - root_mean_squared_error: 0.0979 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1479
# Epoch 58/80
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0096 - root_mean_squared_error: 0.0982 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1497
# Epoch 59/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0093 - root_mean_squared_error: 0.0963 - val_loss: 0.0228 - val_root_mean_squared_error: 0.1512
# Epoch 60/80
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0090 - root_mean_squared_error: 0.0949 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1514
# Epoch 61/80
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0089 - root_mean_squared_error: 0.0945 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1526
# Epoch 62/80
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0089 - root_mean_squared_error: 0.0943 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1537
# Epoch 63/80
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0086 - root_mean_squared_error: 0.0929 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1518
# Epoch 64/80
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0086 - root_mean_squared_error: 0.0926 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1529
# Epoch 65/80
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0086 - root_mean_squared_error: 0.0927 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1541
# Epoch 66/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0085 - root_mean_squared_error: 0.0921 - val_loss: 0.0225 - val_root_mean_squared_error: 0.1501
# Epoch 67/80
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1512
# Epoch 68/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0080 - root_mean_squared_error: 0.0896 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1547
# Epoch 69/80
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0080 - root_mean_squared_error: 0.0897 - val_loss: 0.0232 - val_root_mean_squared_error: 0.1522
# Epoch 70/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0078 - root_mean_squared_error: 0.0885 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1527
# Epoch 71/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0077 - root_mean_squared_error: 0.0878 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1518
# Epoch 72/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0076 - root_mean_squared_error: 0.0875 - val_loss: 0.0240 - val_root_mean_squared_error: 0.1551
# Epoch 73/80
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0074 - root_mean_squared_error: 0.0863 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1544
# Epoch 74/80
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0074 - root_mean_squared_error: 0.0858 - val_loss: 0.0239 - val_root_mean_squared_error: 0.1545
# Epoch 75/80
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0071 - root_mean_squared_error: 0.0845 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1533
# Epoch 76/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0072 - root_mean_squared_error: 0.0850 - val_loss: 0.0240 - val_root_mean_squared_error: 0.1550
# Epoch 77/80
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0070 - root_mean_squared_error: 0.0839 - val_loss: 0.0250 - val_root_mean_squared_error: 0.1581
# Epoch 78/80
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0070 - root_mean_squared_error: 0.0838 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1531
# Epoch 79/80
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0068 - root_mean_squared_error: 0.0823 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1535
# Epoch 80/80
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0067 - root_mean_squared_error: 0.0819 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1543

# %%
plot_predictions2(model2, X3_test, y3_test)
# Out:
# 13/13 [==============================] - 0s 4ms/step
#     ECG Predictions  ECG Actuals  insulin Predictions  insulin Actuals  \
# 0          0.135099     0.240130             0.067903         0.000000
# 1          0.222194     0.248871            -0.015210         0.000000
# 2          0.360194     0.259701            -0.021374         0.869814
# 3          0.316319     0.272770            -0.176745         0.000000
# 4          0.338591     0.288013            -0.041199         0.000000
# 5          0.380443     0.305148            -0.050843         0.000000
# 6          0.333314     0.323676            -0.074130         0.000000
# 7          0.344698     0.342884            -0.003754         0.000000
# 8          0.303678     0.361840             0.017850         0.000000
# 9          0.239546     0.379489            -0.083856         0.000000
# 10         0.283948     0.394790            -0.006073         0.000000
# 11         0.322791     0.406564             0.066235         0.000000
# 12         0.301982     0.413955             0.020128         0.000000
# 13         0.425554     0.416465             0.025564         0.000000
# 14         0.377528     0.413947             0.007769         0.000000
# 15         0.439727     0.406610            -0.021231         0.000000
# 16         0.425204     0.395017            -0.043547         0.000000
# 17         0.459263     0.380058             0.065109         0.000000
# 18         0.491098     0.362648            -0.024305         0.000000
# 19         0.306324     0.344065             0.046464         0.000000
# 20         0.153298     0.325471             0.027287         0.000000
# 21         0.140326     0.307769             0.086601         0.000000
# 22         0.123922     0.291602             0.002257         0.000000
# 23         0.224726     0.277353            -0.040769         0.000000
# 24         0.190422     0.265143             0.015328         0.000000
# 25         0.229117     0.254836            -0.003173         0.000000
# 26         0.191548     0.246158             0.010562         0.000000
# 27         0.210915     0.236486             0.060091         0.000000
# 28         0.200671     0.222706            -0.018257         0.000000
# 29         0.235311     0.202893             0.060428         0.000000
#
#     body_temp Predictions  body_temp Actuals  CGM Predictions  CGM Actuals  \
# 0                0.469357           0.809154         0.866808     0.277247
# 1                0.578602           0.782675         0.784303     0.348732
# 2                0.793778           0.756753         0.763738     0.283904
# 3                0.457283           0.732508         0.702154     0.085858
# 4                0.676325           0.711088         0.821774     0.521791
# 5                0.559439           0.693698         0.729850     0.788553
# 6                0.568421           0.681598         0.691829     0.942709
# 7                0.587995           0.676094         0.702509     0.497294
# 8                0.316574           0.678506         0.605270     0.593781
# 9                0.190620           0.689891         0.550792     0.290815
# 10               0.492160           0.709801         0.666321     0.149081
# 11               0.575786           0.735556         0.714953     0.131789
# 12               0.377582           0.763931         0.637906     0.732421
# 13               0.621530           0.791645         0.660087     0.734530
# 14               0.502436           0.815598         0.640153     0.179278
# 15               0.502460           0.834018         0.638283     0.413545
# 16               0.491784           0.847148         0.650245     0.594172
# 17               0.521036           0.855673         0.601581     0.125197
# 18               0.639306           0.860273         0.648554     0.785442
# 19               0.454687           0.861728         0.700382     0.620026
# 20               0.285962           0.861413         0.714123     0.615254
# 21               0.183667           0.861591         0.710150     0.701261
# 22               0.294161           0.864735         0.766344     0.987304
# 23               0.582471           0.873329         0.671683     0.562414
# 24               0.476527           0.889398         0.712877     0.864508
# 25               0.611055           0.912112         0.781182     0.418694
# 26               0.234906           0.936359         0.778315     0.654511
# 27               0.305667           0.956085         0.784481     0.925368
# 28               0.555701           0.965248         0.793765     0.664195
# 29               0.688891           0.958544         0.824080     0.303039
#
#     RSP Predictions  RSP Actuals
# 0          0.053294     0.066322
# 1          0.059801     0.054176
# 2          0.086090     0.043296
# 3          0.133439     0.033710
# 4          0.044510     0.025440
# 5          0.136058     0.018506
# 6          0.051218     0.012925
# 7          0.053819     0.008708
# 8          0.189022     0.005866
# 9          0.192567     0.004403
# 10         0.074252     0.004322
# 11         0.045663     0.005620
# 12         0.151641     0.008292
# 13         0.097252     0.012329
# 14         0.133323     0.017718
# 15         0.205974     0.024442
# 16         0.204554     0.032483
# 17         0.193109     0.041816
# 18         0.152934     0.052413
# 19         0.123895     0.064245
# 20         0.097259     0.077275
# 21         0.169395     0.091467
# 22         0.116433     0.106780
# 23         0.119597     0.123168
# 24         0.120638     0.140587
# 25         0.149823     0.158984
# 26         0.222578     0.178309
# 27         0.308885     0.198505
# 28         0.297980     0.219516
# 29         0.237004     0.241281

# %%
from keras.layers import GRU
model3 = Sequential()
model3.add(InputLayer((300, 5)))
model3.add(GRU(64))
model3.add(Dense(8, 'relu'))
model3.add(Dense(5, 'linear'))
model3.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 64)                13632
#
#  dense_14 (Dense)            (None, 8)                 520
#
#  dense_15 (Dense)            (None, 5)                 45
#
# =================================================================
# Total params: 14,197
# Trainable params: 14,197
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp3 = ModelCheckpoint('model3/', save_best_only=True)
model3.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])

# %%
model3.fit(X3_train, y3_train, validation_data=(X3_val, y3_val), epochs=20, callbacks=[cp3])
# Out:
# Epoch 1/20
# 60/60 [==============================] - ETA: 0s - loss: 0.0242 - root_mean_squared_error: 0.1557
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 60/60 [==============================] - 11s 186ms/step - loss: 0.0242 - root_mean_squared_error: 0.1557 - val_loss: 0.0223 - val_root_mean_squared_error: 0.1492
# Epoch 2/20
# 60/60 [==============================] - ETA: 0s - loss: 0.0240 - root_mean_squared_error: 0.1548
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 60/60 [==============================] - 11s 180ms/step - loss: 0.0240 - root_mean_squared_error: 0.1548 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1489
# Epoch 3/20
# 60/60 [==============================] - ETA: 0s - loss: 0.0237 - root_mean_squared_error: 0.1541
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 60/60 [==============================] - 11s 183ms/step - loss: 0.0237 - root_mean_squared_error: 0.1541 - val_loss: 0.0220 - val_root_mean_squared_error: 0.1482
# Epoch 4/20
# 60/60 [==============================] - 7s 117ms/step - loss: 0.0236 - root_mean_squared_error: 0.1536 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1486
# Epoch 5/20
# 60/60 [==============================] - 7s 122ms/step - loss: 0.0234 - root_mean_squared_error: 0.1530 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1487
# Epoch 6/20
# 60/60 [==============================] - ETA: 0s - loss: 0.0233 - root_mean_squared_error: 0.1528
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 60/60 [==============================] - 14s 233ms/step - loss: 0.0233 - root_mean_squared_error: 0.1528 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1478
# Epoch 7/20
# 60/60 [==============================] - 9s 144ms/step - loss: 0.0232 - root_mean_squared_error: 0.1524 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1486
# Epoch 8/20
# 60/60 [==============================] - 7s 120ms/step - loss: 0.0232 - root_mean_squared_error: 0.1522 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1486
# Epoch 9/20
# 60/60 [==============================] - ETA: 0s - loss: 0.0231 - root_mean_squared_error: 0.1520
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 60/60 [==============================] - 11s 185ms/step - loss: 0.0231 - root_mean_squared_error: 0.1520 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1476
# Epoch 10/20
# 60/60 [==============================] - 7s 125ms/step - loss: 0.0230 - root_mean_squared_error: 0.1517 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1476
# Epoch 11/20
# 60/60 [==============================] - ETA: 0s - loss: 0.0230 - root_mean_squared_error: 0.1517
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 60/60 [==============================] - 11s 192ms/step - loss: 0.0230 - root_mean_squared_error: 0.1517 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1475
# Epoch 12/20
# 60/60 [==============================] - ETA: 0s - loss: 0.0230 - root_mean_squared_error: 0.1517
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 60/60 [==============================] - 11s 182ms/step - loss: 0.0230 - root_mean_squared_error: 0.1517 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1475
# Epoch 13/20
# 60/60 [==============================] - ETA: 0s - loss: 0.0228 - root_mean_squared_error: 0.1511
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 60/60 [==============================] - 11s 186ms/step - loss: 0.0228 - root_mean_squared_error: 0.1511 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1472
# Epoch 14/20
# 60/60 [==============================] - 7s 117ms/step - loss: 0.0228 - root_mean_squared_error: 0.1511 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1472
# Epoch 15/20
# 60/60 [==============================] - 7s 122ms/step - loss: 0.0228 - root_mean_squared_error: 0.1509 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1473
# Epoch 16/20
# 60/60 [==============================] - 7s 121ms/step - loss: 0.0227 - root_mean_squared_error: 0.1508 - val_loss: 0.0218 - val_root_mean_squared_error: 0.1477
# Epoch 17/20
# 60/60 [==============================] - 7s 121ms/step - loss: 0.0227 - root_mean_squared_error: 0.1507 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1472
# Epoch 18/20
# 60/60 [==============================] - 8s 128ms/step - loss: 0.0226 - root_mean_squared_error: 0.1505 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1473
# Epoch 19/20
# 60/60 [==============================] - 8s 135ms/step - loss: 0.0227 - root_mean_squared_error: 0.1505 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1478
# Epoch 20/20
# 60/60 [==============================] - ETA: 0s - loss: 0.0226 - root_mean_squared_error: 0.1503
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model3\assets
# INFO:tensorflow:Assets written to: model3\assets
# 60/60 [==============================] - 12s 194ms/step - loss: 0.0226 - root_mean_squared_error: 0.1503 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1470

# %%
plot_predictions2(model3, X3_test, y3_test)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\HP\Downloads\Big Iot Healthcare Data Analytics using Deep Learning and Machine Learning\Iot.ipynb Cellule 61 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Downloads/Big%20Iot%20Healthcare%20Data%20Analytics%20using%20Deep%20Learning%20and%20Machine%20Learning/Iot.ipynb#Y113sZmlsZQ%3D%3D?line=0'>1</a> plot_predictions2(model3, X3_test, y3_test)
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Downloads/Big%20Iot%20Healthcare%20Data%20Analytics%20using%20Deep%20Learning%20and%20Machine%20Learning/Iot.ipynb#Y113sZmlsZQ%3D%3D?line=1'>2</a> plt.xlabel("Average Pulse")
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Downloads/Big%20Iot%20Healthcare%20Data%20Analytics%20using%20Deep%20Learning%20and%20Machine%20Learning/Iot.ipynb#Y113sZmlsZQ%3D%3D?line=2'>3</a> plt.ylabel("Calorie Burnage")
#
# NameError: name 'plot_predictions2' is not defined

# %% [markdown]
# ## FIN
